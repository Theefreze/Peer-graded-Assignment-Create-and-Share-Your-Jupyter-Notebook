# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Freddy Rodriguez Data Science

# %% [markdown]
# *I want to become a Data science because is interested how you can leverage of data and helped to growing a business*

# %% [markdown]
# ### my code going to be a mulplication of variables a * b

# %%
a= 5
b=3
print(a*b)
# Out:
# 15

# %% [markdown]
# ![this is an image](attachment:95a71209-0382-4aa2-87c5-253b613f42b1.png)
